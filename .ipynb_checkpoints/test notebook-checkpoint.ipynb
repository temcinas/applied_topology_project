# %%
from graph import *
import spacy

# %%
model = spacy.load('en_vectors_glove_md')

# %%
x = next(iter(model.vocab))

# %%
def most_similar(word, model):
    vect = model(word).vector
    words = []

# %%
x

# %%
for x in model.vocab:
    print(x.lang)
# Out:
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# 500
# ...
